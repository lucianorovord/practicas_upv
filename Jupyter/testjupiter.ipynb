# %%
import pandas as pd

tabla=pd.DataFrame(data = [[1,2],[3,6],[5,10]], columns=['numero', 'cuadrado'])

tabla
# Out:
#    numero  cuadrado
# 0       1         2
# 1       3         6
# 2       5        10
